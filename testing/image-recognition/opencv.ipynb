# %% [markdown]
# # OpenCV Tutorial
#
# Let's get started doing some cool stuff with OpenCV!
#
# ## Using OpenCV with matplotlib
#
# First, let's use OpenCV to open an image, and matplotlib to interactively
# display it.

# %%
import cv2
from matplotlib import pyplot as plt


# Opening image
img = cv2.imread("test-images/pumpkin.jpg")

# OpenCV opens images as BRG
# but we want it as RGB and
# we also need a grayscale
# version
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Creates the environment
# of the picture and shows it
plt.subplot(1, 1, 1)
plt.imshow(img_rgb)
plt.show()
